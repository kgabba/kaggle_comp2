# %% [markdown]
# ### Загрузка датасета

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('train.csv')

# %% [markdown]
# ### EDA

# %%
df.isna().mean()
# Out:
# id                            0.0
# person_age                    0.0
# person_income                 0.0
# person_home_ownership         0.0
# person_emp_length             0.0
# loan_intent                   0.0
# loan_grade                    0.0
# loan_amnt                     0.0
# loan_int_rate                 0.0
# loan_percent_income           0.0
# cb_person_default_on_file     0.0
# cb_person_cred_hist_length    0.0
# loan_status                   0.0
# dtype: float64

# %%
df.describe()
# Out:
#                  id    person_age  person_income  person_emp_length  \
# count  58645.000000  58645.000000   5.864500e+04       58645.000000
# mean   29322.000000     27.550857   6.404617e+04           4.701015
# std    16929.497605      6.033216   3.793111e+04           3.959784
# min        0.000000     20.000000   4.200000e+03           0.000000
# 25%    14661.000000     23.000000   4.200000e+04           2.000000
# 50%    29322.000000     26.000000   5.800000e+04           4.000000
# 75%    43983.000000     30.000000   7.560000e+04           7.000000
# max    58644.000000    123.000000   1.900000e+06         123.000000
#
#           loan_amnt  loan_int_rate  loan_percent_income  \
# count  58645.000000   58645.000000         58645.000000
# mean    9217.556518      10.677874             0.159238
# std     5563.807384       3.034697             0.091692
# min      500.000000       5.420000             0.000000
# 25%     5000.000000       7.880000             0.090000
# 50%     8000.000000      10.750000             0.140000
# 75%    12000.000000      12.990000             0.210000
# max    35000.000000      23.220000             0.830000
#
#        cb_person_cred_hist_length   loan_status
# count                58645.000000  58645.000000
# mean                     5.813556      0.142382
# std                      4.029196      0.349445
# min                      2.000000      0.000000
# 25%                      3.000000      0.000000
# 50%                      4.000000      0.000000
# 75%                      8.000000      0.000000
# max                     30.000000      1.000000

# %%
df.describe(include='object')
# Out:
#        person_home_ownership loan_intent loan_grade cb_person_default_on_file
# count                  58645       58645      58645                     58645
# unique                     4           6          7                         2
# top                     RENT   EDUCATION          A                         N
# freq                   30594       12271      20984                     49943

# %%
df = df[df['person_age'] < 85]

# %% [markdown]
# ### Train-test

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(['id', 'loan_status'], axis=1)
y = df['loan_status']

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, stratify=y, random_state=22, train_size=0.8)

# %%
len(Xtrain) == len(ytrain)
# Out:
# True

# %% [markdown]
# ### Preprocessing

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import PolynomialFeatures

# %%
nonum_pipe = Pipeline([('ohe', OneHotEncoder(drop='first'))])

# %%
num_pipe = Pipeline([('minmax', MinMaxScaler()), 
               ('feature_eng', PolynomialFeatures(include_bias=False))])

# %%
ct_preproc = ColumnTransformer([('num', num_pipe, X.select_dtypes(include='number').columns),
                               ('nonum', nonum_pipe, X.select_dtypes(exclude='number').columns)])

# %% [markdown]
# ### Baseline

# %% [markdown]
# ### catboost test hyperparametrs (with error)

# %%
from sklearn.model_selection import RandomizedSearchCV
from catboost import CatBoostClassifier
from sklearn.pipeline import FunctionTransformer
from sklearn.feature_selection import SelectKBest

# %%
def to_df(X):
    df = pd.DataFrame(X, columns=ct_cat.get_feature_names_out())
    df = df.apply(pd.to_numeric, errors='ignore')
    global cat_features
    cat_features = list(df.select_dtypes(exclude='number').columns)
    return df
    
ct_cat = ColumnTransformer([('poly_cat', PolynomialFeatures(), X.select_dtypes(include='number').columns)], remainder='passthrough')

cat_pipe = Pipeline([('ct_category', ct_cat),
                     ('to_fr', FunctionTransformer(to_df)),
                    ('cat', CatBoostClassifier(verbose=0, cat_features=cat_features))])

# %%
cat_pipe.fit(Xtrain[:50], ytrain[:50])
# Out:
# C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py:1667: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('ct_category',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('poly_cat',
#                                                   PolynomialFeatures(),
#                                                   Index(['person_age', 'person_income', 'person_emp_length', 'loan_amnt',
#        'loan_int_rate', 'loan_percent_income', 'cb_person_cred_hist_length'],
#       dtype='object'))])),
#                 ('to_fr',
#                  FunctionTransformer(func=<function to_df at 0x0000019E39B689A0>)),
#                 ('cat',
#                  <catboost.core.CatBoostClassifier object at 0x0000019E369442D0>)])

# %%
params_cat = {'cat__iterations': [100, 300, 500, 1000],  
    'cat__learning_rate': [0.01, 0.03, 0.1, 0.3],  
    'cat__max_depth': [4, 6, 8],  
    'cat__l2_leaf_reg': [1, 3, 5, 7, 9],
              'ct_category__poly_cat__degree':[1,2,3]}

# %%
cat_mode = RandomizedSearchCV(cat_pipe, params_cat, cv=4, n_jobs=-1, scoring='roc_auc', n_iter=17)

# %%
cat_mode.fit(Xtrain[:50], ytrain[:50])
# Out:
# C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 44 fits failed out of a total of 68.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 14 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 654, in fit
#     Xt = self._fit(X, y, routed_params, raw_params=params)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 588, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\joblib\memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 1551, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\base.py", line 921, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\preprocessing\_function_transformer.py", line 260, in transform
#     out = self._transform(X, func=self.func, kw_args=self.kw_args)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\preprocessing\_function_transformer.py", line 387, in _transform
#     return func(X, **(kw_args if kw_args else {}))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\AppData\Local\Temp\ipykernel_17032\448540421.py", line 2, in to_df
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\pandas\core\frame.py", line 782, in __init__
#     mgr = ndarray_to_mgr(
#           ^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\pandas\core\internals\construction.py", line 336, in ndarray_to_mgr
#     _check_values_indices_shape_match(values, index, columns)
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\pandas\core\internals\construction.py", line 420, in _check_values_indices_shape_match
#     raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
# ValueError: Shape of passed values is (37, 12), indices imply (37, 40)
#
# --------------------------------------------------------------------------------
# 14 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 654, in fit
#     Xt = self._fit(X, y, routed_params, raw_params=params)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 588, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\joblib\memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 1551, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\base.py", line 921, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\preprocessing\_function_transformer.py", line 260, in transform
#     out = self._transform(X, func=self.func, kw_args=self.kw_args)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\preprocessing\_function_transformer.py", line 387, in _transform
#     return func(X, **(kw_args if kw_args else {}))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\AppData\Local\Temp\ipykernel_17032\448540421.py", line 2, in to_df
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\pandas\core\frame.py", line 782, in __init__
#     mgr = ndarray_to_mgr(
#           ^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\pandas\core\internals\construction.py", line 336, in ndarray_to_mgr
#     _check_values_indices_shape_match(values, index, columns)
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\pandas\core\internals\construction.py", line 420, in _check_values_indices_shape_match
#     raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
# ValueError: Shape of passed values is (38, 12), indices imply (38, 40)
#
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 654, in fit
#     Xt = self._fit(X, y, routed_params, raw_params=params)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 588, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\joblib\memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 1551, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\base.py", line 921, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\preprocessing\_function_transformer.py", line 260, in transform
#     out = self._transform(X, func=self.func, kw_args=self.kw_args)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\preprocessing\_function_transformer.py", line 387, in _transform
#     return func(X, **(kw_args if kw_args else {}))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\AppData\Local\Temp\ipykernel_17032\448540421.py", line 2, in to_df
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\pandas\core\frame.py", line 782, in __init__
#     mgr = ndarray_to_mgr(
#           ^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\pandas\core\internals\construction.py", line 336, in ndarray_to_mgr
#     _check_values_indices_shape_match(values, index, columns)
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\pandas\core\internals\construction.py", line 420, in _check_values_indices_shape_match
#     raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
# ValueError: Shape of passed values is (37, 124), indices imply (37, 40)
#
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 654, in fit
#     Xt = self._fit(X, y, routed_params, raw_params=params)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 588, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\joblib\memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 1551, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\base.py", line 921, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\preprocessing\_function_transformer.py", line 260, in transform
#     out = self._transform(X, func=self.func, kw_args=self.kw_args)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\preprocessing\_function_transformer.py", line 387, in _transform
#     return func(X, **(kw_args if kw_args else {}))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\AppData\Local\Temp\ipykernel_17032\448540421.py", line 2, in to_df
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\pandas\core\frame.py", line 782, in __init__
#     mgr = ndarray_to_mgr(
#           ^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\pandas\core\internals\construction.py", line 336, in ndarray_to_mgr
#     _check_values_indices_shape_match(values, index, columns)
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\pandas\core\internals\construction.py", line 420, in _check_values_indices_shape_match
#     raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
# ValueError: Shape of passed values is (38, 124), indices imply (38, 40)
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [0.90909091        nan        nan        nan 0.89772727 0.90909091
#         nan        nan        nan        nan 0.76136364 0.90909091
#         nan        nan        nan 0.89772727        nan]
#   warnings.warn(
# C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py:1667: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# RandomizedSearchCV(cv=4,
#                    estimator=Pipeline(steps=[('ct_category',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('poly_cat',
#                                                                                PolynomialFeatures(),
#                                                                                Index(['person_age', 'person_income', 'person_emp_length', 'loan_amnt',
#        'loan_int_rate', 'loan_percent_income', 'cb_person_cred_hist_length'],
#       dtype='object'))])),
#                                              ('to_fr',
#                                               FunctionTransformer(func=<function to_df at 0x0000019E39B689A0>)),
#                                              ('cat',
#                                               <catboost.core.CatBoostClassifier object at 0x0000019E369442D0>)]),
#                    n_iter=17, n_jobs=-1,
#                    param_distributions={'cat__iterations': [100, 300, 500,
#                                                             1000],
#                                         'cat__l2_leaf_reg': [1, 3, 5, 7, 9],
#                                         'cat__learning_rate': [0.01, 0.03, 0.1,
#                                                                0.3],
#                                         'cat__max_depth': [4, 6, 8],
#                                         'ct_category__poly_cat__degree': [1, 2,
#                                                                           3]},
#                    scoring='roc_auc')

# %%
cat_mode.best_score_
# Out:
# 0.9090909090909092

# %%
cat_mode.best_score_
# Out:
# 0.9481633903878303

# %%
cat_mode.best_params_
# Out:
# {'ct_category__poly_cat__degree': 2,
#  'cat__max_depth': 6,
#  'cat__learning_rate': 0.1,
#  'cat__l2_leaf_reg': 7,
#  'cat__iterations': 500}

# %%
cat_mode.best_estimator_.named_steps['cat'].get_feature_importance(prettified=True)
# Out:
#                                            Feature Id  Importances
# 0                    remainder__person_home_ownership    14.570300
# 1                       poly_cat__loan_percent_income    12.328204
# 2                               remainder__loan_grade    10.352306
# 3                              remainder__loan_intent     9.080523
# 4                             poly_cat__person_income     8.412421
# 5                           poly_cat__person_income^2     7.337766
# 6                           poly_cat__loan_int_rate^2     5.704876
# 7                     poly_cat__loan_percent_income^2     5.363114
# 8                             poly_cat__loan_int_rate     3.008930
# 9         poly_cat__loan_int_rate loan_percent_income     1.937079
# 10          poly_cat__person_emp_length loan_int_rate     1.454398
# 11                 poly_cat__person_age loan_int_rate     1.251952
# 12        poly_cat__person_income loan_percent_income     1.221324
# 13              poly_cat__person_income loan_int_rate     1.197892
# 14  poly_cat__loan_int_rate cb_person_cred_hist_le...     1.195821
# 15           poly_cat__person_age loan_percent_income     1.146180
# 16             poly_cat__person_age person_emp_length     0.970538
# 17            poly_cat__loan_amnt loan_percent_income     0.951884
# 18                  poly_cat__person_income loan_amnt     0.899045
# 19     poly_cat__loan_amnt cb_person_cred_hist_length     0.856268
# 20                  poly_cat__loan_amnt loan_int_rate     0.842476
# 21          poly_cat__person_income person_emp_length     0.835683
# 22              poly_cat__person_emp_length loan_amnt     0.828970
# 23                      poly_cat__person_emp_length^2     0.735506
# 24                 poly_cat__person_age person_income     0.732797
# 25  poly_cat__person_income cb_person_cred_hist_le...     0.729520
# 26  poly_cat__loan_percent_income cb_person_cred_h...     0.706815
# 27                     poly_cat__person_age loan_amnt     0.650519
# 28                        poly_cat__person_emp_length     0.647720
# 29  poly_cat__person_emp_length cb_person_cred_his...     0.625837
# 30    poly_cat__person_emp_length loan_percent_income     0.623332
# 31    poly_cat__person_age cb_person_cred_hist_length     0.604078
# 32                             poly_cat__person_age^2     0.570977
# 33                                poly_cat__loan_amnt     0.482317
# 34                              poly_cat__loan_amnt^2     0.474969
# 35                               poly_cat__person_age     0.455932
# 36               remainder__cb_person_default_on_file     0.103358
# 37             poly_cat__cb_person_cred_hist_length^2     0.058278
# 38               poly_cat__cb_person_cred_hist_length     0.050092
# 39                                        poly_cat__1     0.000000

# %%
test = pd.read_csv('test.csv')

# %%
Xt = test.drop('id', axis=1)
test['loan_status'] = cat_mode.best_estimator_.predict(Xt)

# %%
test[['id', 'loan_status']].to_csv('pipe_pred.csv', index=False)

# %% [markdown]
# ### Linear models

# %%
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import MinMaxScaler

# %%
mod_base = cross_val_score(SVC(class_weight='balanced'), Xtrain.select_dtypes(include='number'), ytrain, cv=5, scoring='roc_auc')

# %%
np.mean(mod_base)
# Out:
# 0.7786289605454184

# %%
pipe_num = Pipeline([('pipe_n', MinMaxScaler()),
             ('selector', SelectKBest())])

ct_svc = ColumnTransformer([('obj', OneHotEncoder(drop='first'), Xtrain.select_dtypes(exclude='number').columns),
                  ('num', pipe_num, Xtrain.select_dtypes(include='number').columns)])

# %%
pipe_svc = Pipeline([('ct', ct_svc),
                    ('svc', SVC(class_weight='balanced'))])

params_svc = { 'svc__C': [120, 130, 150, 170],                  # Регуляризация
    'svc__kernel': ['rbf', 'poly'],      # ЯдраF
    'svc__degree': [2, 3], 
              'ct__num__selector__k':[6,7,8]}

svc_mod = RandomizedSearchCV(pipe_svc, params_svc, n_jobs=-1, scoring='roc_auc', cv=5)

# %%
svc_mod.fit(Xtrain, ytrain)
# Out:
# C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:783: UserWarning: k=8 is greater than n_features=7. All the features will be returned.
#   warnings.warn(
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('ct',
#                                               ColumnTransformer(transformers=[('obj',
#                                                                                OneHotEncoder(drop='first'),
#                                                                                Index(['person_home_ownership', 'loan_intent', 'loan_grade',
#        'cb_person_default_on_file'],
#       dtype='object')),
#                                                                               ('num',
#                                                                                Pipeline(steps=[('pipe_n',
#                                                                                                 MinMaxScaler()),
#                                                                                                ('selector',
#                                                                                                 SelectKBest())]),
#                                                                                Index(['person_age', 'person_income', 'person_emp_length', 'loan_amnt',
#        'loan_int_rate', 'loan_percent_income', 'cb_person_cred_hist_length'],
#       dtype='object'))])),
#                                              ('svc',
#                                               SVC(class_weight='balanced'))]),
#                    n_jobs=-1,
#                    param_distributions={'ct__num__selector__k': [6, 7, 8],
#                                         'svc__C': [120, 130, 150, 170],
#                                         'svc__degree': [2, 3],
#                                         'svc__kernel': ['rbf', 'poly']},
#                    scoring='roc_auc')

# %%
svc_mod.best_score_, svc_mod.best_params_
# Out:
# (0.9181019593719235,
#  {'svc__kernel': 'poly',
#   'svc__degree': 2,
#   'svc__C': 150,
#   'ct__num__selector__k': 8})

# %%
svc_mod.best_score_, svc_mod.best_params_
# Out:
# (0.9181019593719235,
#  {'svc__kernel': 'poly',
#   'svc__degree': 2,
#   'svc__C': 150,
#   'ct__num__selector__k': 8})

# %% [markdown]
# ### Logreg

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LogisticRegression

# %%
pipe_num_log = Pipeline([('pipe_n', MinMaxScaler()),
                     ('poly_f', PolynomialFeatures(include_bias=False)),
             ('selector', SelectKBest())])

ct_log = ColumnTransformer([('obj', OneHotEncoder(drop='first'), Xtrain.select_dtypes(exclude='number').columns),
                  ('num', pipe_num_log, Xtrain.select_dtypes(include='number').columns)])

# %%
pipe_las = Pipeline([('ct', ct_log),
                    ('log', LogisticRegression())])

params_las = { 'log__C': [5, 8, 10, 15, 20],      # Обратная сила регуляризации (1/alpha)
    'log__penalty': ['l1'],                    # L1-регуляризация
    'log__solver': ['liblinear'],      # Решатели, поддерживающие L1
    'log__max_iter': [40, 80, 100, 150],
              'ct__num__selector__k':[6,7,8],
             'ct__num__poly_f__degree':[None,2]}

log_mod = RandomizedSearchCV(pipe_las, params_las, n_jobs=-1, scoring='roc_auc', cv=4)

# %%
log_mod.fit(Xtrain, ytrain)
# Out:
# C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 24 fits failed out of a total of 40.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 24 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 654, in fit
#     Xt = self._fit(X, y, routed_params, raw_params=params)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 588, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\joblib\memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 1551, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py", line 1001, in fit_transform
#     result = self._call_func_on_transformers(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py", line 910, in _call_func_on_transformers
#     return Parallel(n_jobs=self.n_jobs)(jobs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\utils\parallel.py", line 77, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\joblib\parallel.py", line 1088, in __call__
#     while self.dispatch_one_batch(iterator):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\joblib\parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\joblib\parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\joblib\_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#                    ^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\joblib\parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\joblib\parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\utils\parallel.py", line 139, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 1551, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 718, in fit_transform
#     Xt = self._fit(X, y, routed_params)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 588, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\joblib\memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 1551, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\base.py", line 921, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'degree' parameter of PolynomialFeatures must be an int in the range [0, inf) or an array-like. Got None instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\9b_gr\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [0.90691613        nan 0.90691338        nan 0.90693254        nan
#  0.90692395        nan        nan        nan]
#   warnings.warn(
# RandomizedSearchCV(cv=4,
#                    estimator=Pipeline(steps=[('ct',
#                                               ColumnTransformer(transformers=[('obj',
#                                                                                OneHotEncoder(drop='first'),
#                                                                                Index(['person_home_ownership', 'loan_intent', 'loan_grade',
#        'cb_person_default_on_file'],
#       dtype='object')),
#                                                                               ('num',
#                                                                                Pipeline(steps=[('pipe_n',
#                                                                                                 MinMaxScaler()),
#                                                                                                ('poly_f',
#                                                                                                 PolynomialFeatures(include_bias=False)),
#                                                                                                ('selector',
#                                                                                                 SelectKBest(...
#                                                                                Index(['person_age', 'person_income', 'person_emp_length', 'loan_amnt',
#        'loan_int_rate', 'loan_percent_income', 'cb_person_cred_hist_length'],
#       dtype='object'))])),
#                                              ('log', LogisticRegression())]),
#                    n_jobs=-1,
#                    param_distributions={'ct__num__poly_f__degree': [None, 2],
#                                         'ct__num__selector__k': [6, 7, 8],
#                                         'log__C': [5, 8, 10, 15, 20],
#                                         'log__max_iter': [40, 80, 100, 150],
#                                         'log__penalty': ['l1'],
#                                         'log__solver': ['liblinear']},
#                    scoring='roc_auc')

# %%
log_mod.best_score_, log_mod.best_params_
# Out:
# (0.9069747977637368,
#  {'log__solver': 'liblinear',
#   'log__penalty': 'l1',
#   'log__max_iter': 100,
#   'log__C': 10,
#   'ct__num__selector__k': 7,
#   'ct__num__poly_f__degree': 2})

# %%
log_mod.best_score_, log_mod.best_params_
# Out:
# (0.9069325410627118,
#  {'log__solver': 'liblinear',
#   'log__penalty': 'l1',
#   'log__max_iter': 80,
#   'log__C': 10,
#   'ct__num__selector__k': 7,
#   'ct__num__poly_f__degree': 2})

# %% [markdown]
# ### XGBoost

# %%
from xgboost import XGBClassifier

# %%
pipe_num_xgb = Pipeline([('pipe_n', MinMaxScaler()),
                     ('poly_f', PolynomialFeatures(include_bias=False)),
             ('selector', SelectKBest())])

ct_xgb = ColumnTransformer([('obj', OneHotEncoder(drop='first'), Xtrain.select_dtypes(exclude='number').columns),
                  ('num', pipe_num_xgb, Xtrain.select_dtypes(include='number').columns)])

# %%
pipe_xgb = Pipeline([('ct', ct_xgb),
                    ('xgb', XGBClassifier())])

params_xgb = {   # Важные параметры
    'xgb__n_estimators': [300, 500, 800],       # Количество деревьев
    'xgb__max_depth': [8, 9, 11, 14],                 # Глубина деревьев
    'xgb__learning_rate': [0.03, 0.05, 0.08],    # Скорость обучения
    'xgb__subsample': [0.4, 0.5, 0.6],              
    'xgb__colsample_bytree': [0.4, 0.6,0.7],       
    'xgb__gamma': [ 0.3, 0.4, 0.6],                     # Минимальный loss для split
    'xgb__reg_alpha': [0.05, 0.1, 0.2],
              'ct__num__selector__k':[ 9, 10, 12],
             'ct__num__poly_f__degree':[2,3]}

mod_xgb = RandomizedSearchCV(pipe_xgb, params_xgb, n_jobs=-1, scoring='roc_auc', cv=4)

# %%
mod_xgb.fit(Xtrain, ytrain)
# Out:
# RandomizedSearchCV(cv=4,
#                    estimator=Pipeline(steps=[('ct',
#                                               ColumnTransformer(transformers=[('obj',
#                                                                                OneHotEncoder(drop='first'),
#                                                                                Index(['person_home_ownership', 'loan_intent', 'loan_grade',
#        'cb_person_default_on_file'],
#       dtype='object')),
#                                                                               ('num',
#                                                                                Pipeline(steps=[('pipe_n',
#                                                                                                 MinMaxScaler()),
#                                                                                                ('poly_f',
#                                                                                                 PolynomialFeatures(include_bias=False)),
#                                                                                                ('selector',
#                                                                                                 SelectKBest(...
#                                                             num_parallel_tree=None, ...))]),
#                    n_jobs=-1,
#                    param_distributions={'ct__num__poly_f__degree': [2, 3],
#                                         'ct__num__selector__k': [9, 10, 12],
#                                         'xgb__colsample_bytree': [0.4, 0.6,
#                                                                   0.7],
#                                         'xgb__gamma': [0.3, 0.4, 0.6],
#                                         'xgb__learning_rate': [0.03, 0.05,
#                                                                0.08],
#                                         'xgb__max_depth': [8, 9, 11, 14],
#                                         'xgb__n_estimators': [300, 500, 800],
#                                         'xgb__reg_alpha': [0.05, 0.1, 0.2],
#                                         'xgb__subsample': [0.4, 0.5, 0.6]},
#                    scoring='roc_auc')

# %%
mod_xgb.best_score_, mod_xgb.best_params_
# Out:
# (0.9476737852423799,
#  {'xgb__subsample': 0.6,
#   'xgb__reg_alpha': 0.2,
#   'xgb__n_estimators': 500,
#   'xgb__max_depth': 9,
#   'xgb__learning_rate': 0.03,
#   'xgb__gamma': 0.6,
#   'xgb__colsample_bytree': 0.7,
#   'ct__num__selector__k': 12,
#   'ct__num__poly_f__degree': 2})

# %%
mod_xgb.best_score_, mod_xgb.best_params_
# Out:
# (0.9494196816875388,
#  {'xgb__subsample': 0.6,
#   'xgb__reg_alpha': 0.1,
#   'xgb__n_estimators': 300,
#   'xgb__max_depth': 8,
#   'xgb__learning_rate': 0.05,
#   'xgb__gamma': 0.3,
#   'xgb__colsample_bytree': 0.7,
#   'ct__num__selector__k': 9,
#   'ct__num__poly_f__degree': 2})

# %% [markdown]
# ### Stacking mod

# %%
from sklearn.ensemble import StackingClassifier

# %%
estimators = [('fst', svc_mod.best_estimator_),
             ('scd', log_mod.best_estimator_),
             ('thrd', mod_xgb.best_estimator_)]

# %%
stack_mod = StackingClassifier(estimators, final_estimator=LogisticRegression(),cv=5, n_jobs=-1, passthrough=False)

# %%
stack_mod.fit(Xtrain, ytrain)
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('fst',
#                                 Pipeline(steps=[('ct',
#                                                  ColumnTransformer(transformers=[('obj',
#                                                                                   OneHotEncoder(drop='first'),
#                                                                                   Index(['person_home_ownership', 'loan_intent', 'loan_grade',
#        'cb_person_default_on_file'],
#       dtype='object')),
#                                                                                  ('num',
#                                                                                   Pipeline(steps=[('pipe_n',
#                                                                                                    MinMaxScaler()),
#                                                                                                   ('selector',
#                                                                                                    SelectKBest(k=8))]),
#                                                                                   Index(['person_age', 'person_incom...
#                                                                importance_type=None,
#                                                                interaction_constraints=None,
#                                                                learning_rate=0.03,
#                                                                max_bin=None,
#                                                                max_cat_threshold=None,
#                                                                max_cat_to_onehot=None,
#                                                                max_delta_step=None,
#                                                                max_depth=9,
#                                                                max_leaves=None,
#                                                                min_child_weight=None,
#                                                                missing=nan,
#                                                                monotone_constraints=None,
#                                                                multi_strategy=None,
#                                                                n_estimators=500,
#                                                                n_jobs=None,
#                                                                num_parallel_tree=None, ...))]))],
#                    final_estimator=LogisticRegression(), n_jobs=-1)

# %%
from sklearn.metrics import roc_auc_score

# %%
stack_mod.
# Out:
# array(['stackingclassifier_fst', 'stackingclassifier_scd',
#        'stackingclassifier_thrd'], dtype=object)

# %%
roc_auc_score(ytest, stack_mod.predict(Xtest))
# Out:
# 0.8463864992948789
